# %%
print("HEllo WOrld")
# Out:
# HEllo WOrld

# %% [markdown]
# ##Heading

# %% [markdown]
# #Heading

# %% [markdown]
# Head

# %% [markdown]
# # comment

# %% [markdown]
# ## Heading

# %%
a=10
print(a)
# Out:
# 10

# %%
a=2
print(a)
# Out:
# 2

# %% [markdown]
# #comment

# %% [markdown]
# ## ctrl+enter

# %% [markdown]
# ### Adinath ## Saurabh #Pratik

# %% [markdown]
# #comment

# %% [markdown]
# #comment
