# %%
import numpy as np

# %%
arr2d= arr.reshape(3,3)
arr2d

# %%
arr= np.arange(1,10)
arr

# %%
arr

# %%
arr2d

# %% [markdown]
# ## Basic Function

# %%
arr2d.ravel()

# %%
arr2d.flatten('F') #F: Fortan return values column wise

# %%
arr2d

# %%
arr2d.flatten('C') #C: stryle return values column wise

# %%
np.linspace(1,3,100) #divide 1 to 3 into 100 pieces

# %%
arr2d

# %%
arr4=np.arange(1,10).reshape((3,3))
arr4

# %%
arr4.ravel()

# %%
arr4

# %% [markdown]
# ## Mathematical Functions

# %%
arr1=np.arange(1,10).reshape((3,3))
arr2=np.arange(3,12).reshape((3,3))
arr1,arr2

# %%
np.add(arr1,arr2)

# %%
arr1+arr2

# %%
np.subtract(arr2,arr1)

# %%
arr1-arr2

# %%
np.multiply(arr2,arr1)

# %%
arr2*arr1

# %%
np.divide(arr2,arr1)

# %%
arr2/arr1

# %%
arr3=np.array([10])
arr4=np.array([10,20,30])

# %%
arr1+arr3

# %%
arr1+arr4

# %%
arr1,arr3

# %%
arr1,arr2

# %%
np.dot(arr1,arr2)

# %%
np.sqrt(arr1)

# %%
np.log(arr1)

# %%
np.log10(arr1)

# %%
np.concatenate([arr1,arr2]) #No of columns should be same

# %%
np.concatenate([arr1,arr2],axis=1) #No of rows should be same axis1 is column axis0=row default is 0

# %% [markdown]
# ## splitting

# %%
arr1

# %%
np.split(arr1,3)

# %%
np.split(arr1,3,axis=1) #you can only split in equal parts

# %%
arr1

# %%
arr1.min()

# %%
arr1.argmin()

# %%
arr2.max()

# %%
arr2.argmax()
