# %%
# %%time
import pandas as pd
# Out:
# CPU times: total: 281 ms
# Wall time: 1.18 s

# %% [markdown]
# ## Intro
# 1. pd.Series()
# 2. Heterogeneous
# 3. Ordered
# 4. Mutable, Size-Immutable
# 5. Duplicate allowed

# %%
s1= pd.Series([10,20,30,'abc',30])
s1
# Out:
# 0     10
# 1     20
# 2     30
# 3    abc
# 4     30
# dtype: object

# %%
s1=pd.Series([10,20,30,40],index=['a','b','c','d'])
s1
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s1
# Out:
# 0     10
# 1     20
# 2     30
# 3    abc
# 4     30
# dtype: object

# %%
s2= pd.Series([50,60,70,50],index=['u','i','o','p'])
s2
# Out:
# u    50
# i    60
# o    70
# p    50
# dtype: int64

# %%
s1
# Out:
# 0     10
# 1     20
# 2     30
# 3    abc
# 4     30
# dtype: object

# %%
s1.sum()
# Out:
# np.int64(100)

# %%
s1.mean()
# Out:
# np.float64(25.0)

# %%
s1.median()
# Out:
# np.float64(25.0)

# %%
s1.std()
# Out:
# np.float64(12.909944487358056)

# %%
s1
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s1.loc['a']
# Out:
# np.int64(10)

# %%
s1.iloc[0]
# Out:
# np.int64(10)
