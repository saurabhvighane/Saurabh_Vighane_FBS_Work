# %% [markdown]
# ## Pandas Introduction
# 1. Powerful python data analysis libraries.
# 2. Behind numpy array is implemented.
# 3. Used for load datasets (from files eg.csv,tsv,excel etc.)

# %% [markdown]
# ## Data Structure
# 1. Series(1D)
# 2. DataFrame(2D)
# 3. Panel(3D)
