# %% [markdown]
# ## Dataframe Introduction
# 1.DataFrame()
# 2.Heterogeneous
# 3.Ordered
# 4.Mutable,Size-Mutable
# 5.Duplication allowed
# 6.2D datastructure of pandas
# 7.Row and columns

# %%
import pandas as pd

# %%
df=pd.DataFrame()
type(df)

# %%
df=pd.DataFrame([[10,'Saurabh',90000],
                 [11,'Pratik',70000],
                 [12,'Adinath',80000]],
                columns=['ID','Name','Sal'])
df

# %%
df['ID']

# %%
df2=pd.DataFrame({'ID':[101,102,103],
                  'Name':['Omkar','Parth','Sainath'],
                  'SAL':[40000,50000,60000]})
df2

# %%
df2=df2.set_index('ID')

# %%
df2.loc[102]

# %%
df2.iloc[0]

# %%
df2.iloc[:2]
# in iloc last in range is not considered

# %%
df2.loc[:102]
# in loc last range element is condsidered

# %%
iris=pd.read_csv("C:/Users/saura/Downloads/anime/one piece/Iris.csv")
iris

# %%
iris.head()

# %%
iris.tail(10)

# %%
iris.info()

# %%
iris.describe()

# %%
iris.tail()

# %%
iris['Sepal_Width'].mean()

# %%
iris['Sepal_Length'].agg(['mean','max','min','sum'])

# %%
iris['Sepal_Length'].unique()

# %%
iris['Species'].unique()

# %%
iris['Species'].value_counts()

# %%
iris.drop(['Species'],axis=1)
# This will not change into original dataset

# %%
iris.head()

# %%
iris.drop(['Species'],axis=1,inplace=True)
# This will change into original dataset

# %%
iris.head()

# %%
iris.drop(0,inplace=True)

# %%
iris.head()

# %%
df

# %%
df['Address']= ['Pune','Mumbai','Nashik']   #add column

# %%
df

# %%
df.loc[2]= [104,'Pravin',70000,'Nagar']

# %%
df

# %%
df.loc[2]= [3,'Adinath',70000,'Nagar']  #add row

# %%
df
