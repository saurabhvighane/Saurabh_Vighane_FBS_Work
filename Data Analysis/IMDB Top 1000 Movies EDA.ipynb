# %% [markdown]
# # IMDb Top 1000 Movies - EDA

# %% [markdown]
# ## 1. Import Libraries & Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/saura/OneDrive/Desktop/FBS/Data Analysis/Datasets-20260831T104834Z-1-001/Datasets/imdb_top_1000.csv")

# %% [markdown]
# ## 2. Data Overview

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.tail()
# Out:
#                                            Poster_Link  \
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
df.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %%
df.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06

# %%
df.describe(include='object')
# Out:
#                                               Poster_Link Series_Title  \
# count                                                1000         1000
# unique                                               1000          999
# top     https://m.media-amazon.com/images/M/MV5BMTY5OD...     Drishyam
# freq                                                    1            2
#
#        Released_Year Certificate  Runtime  Genre  \
# count           1000         899     1000   1000
# unique           100          16      140    202
# top             2014           U  100 min  Drama
# freq              32         234       23     85
#
#                                                  Overview          Director  \
# count                                                1000              1000
# unique                                               1000               548
# top     A man in London tries to help a counter-espion...  Alfred Hitchcock
# ...

# %% [markdown]
# ## 3. Data Quality Check

# %%
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Poster_Link      1000
# Series_Title      999
# Released_Year     100
# Certificate        16
# Runtime           140
# Genre             202
# IMDB_Rating        17
# Overview         1000
# Meta_score         63
# Director          548
# Star1             660
# Star2             841
# Star3             891
# Star4             939
# No_of_Votes       999
# Gross             823
# dtype: int64

# %% [markdown]
# ## 4. Data Cleaning

# %%
df['Released_Year'].head()
# Out:
# 0    1994
# 1    1972
# 2    2008
# 3    1974
# 4    1957
# Name: Released_Year, dtype: object

# %%
df['Released_Year'].dtype
# Out:
# dtype('O')

# %%
df['Released_Year'] = pd.to_numeric(df['Released_Year'], errors='coerce')

# %%
df['Released_Year'].dtype
# Out:
# dtype('float64')

# %%
df['Released_Year'].isnull().sum()
# Out:
# np.int64(1)

# %%
df[df['Released_Year'].isnull()]
# Out:
#                                            Poster_Link Series_Title  \
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
#
#      Released_Year Certificate  Runtime                      Genre  \
# 966            NaN           U  140 min  Adventure, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 966          7.6  NASA must devise a strategy to return Apollo 1...
#
#      Meta_score    Director      Star1        Star2        Star3        Star4  \
# 966        77.0  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      No_of_Votes        Gross
# 966       269197  173,837,933

# %%
df.loc[df['Series_Title'] == 'Apollo 13', 'Released_Year'] = 1995

# %%
df['Released_Year'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Runtime'].head()
# Out:
# 0    142 min
# 1    175 min
# 2    152 min
# 3    202 min
# 4     96 min
# Name: Runtime, dtype: object

# %%
df['Runtime'].dtype
# Out:
# dtype('O')

# %%
df['Runtime'] = df['Runtime'].str.replace(' min', '', regex=False)

# %%
df['Runtime'].head()
# Out:
# 0    142
# 1    175
# 2    152
# 3    202
# 4     96
# Name: Runtime, dtype: object

# %%
df['Runtime'] = pd.to_numeric(df['Runtime'], errors='coerce')

# %%
df['Runtime'].dtype
# Out:
# dtype('int64')

# %%
df['Runtime'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Gross'].head()
# Out:
# 0     28,341,469
# 1    134,966,411
# 2    534,858,444
# 3     57,300,000
# 4      4,360,000
# Name: Gross, dtype: object

# %%
df['Gross'].dtype
# Out:
# dtype('O')

# %%
df['Gross'] = df['Gross'].str.replace(',', '', regex=False)

# %%
df['Gross'] = pd.to_numeric(df['Gross'], errors='coerce')

# %%
df['Gross'].dtype
# Out:
# dtype('float64')

# %%
df['Gross'].isnull().sum()
# Out:
# np.int64(169)

# %%
df.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year    float64
# Certificate       object
# Runtime            int64
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross            float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df['Certificate'].isnull().sum()
# Out:
# np.int64(101)

# %%
df['Certificate'] = df['Certificate'].fillna('Unknown')

# %%
df['Certificate'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Certificate'].value_counts()
# Out:
# Certificate
# U           234
# A           197
# UA          175
# R           146
# Unknown     101
# PG-13        43
# PG           37
# Passed       34
# G            12
# Approved     11
# TV-PG         3
# GP            2
# TV-14         1
# Unrated       1
# TV-MA         1
# 16            1
# U/A           1
# Name: count, dtype: int64

# %%
df['Meta_score'].isnull().sum()
# Out:
# np.int64(157)

# %%
# No requirement to change it

# %%
df['Gross'].isnull().sum()
# Out:
# np.int64(169)

# %%
# No requirement to change it

# %%
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate        0
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %% [markdown]
# ## 6. Descriptive Statistics

# %%
df.describe()
# Out:
#        Released_Year      Runtime  IMDB_Rating  Meta_score   No_of_Votes  \
# count    1000.000000  1000.000000  1000.000000  843.000000  1.000000e+03
# mean     1991.221000   122.891000     7.949300   77.971530  2.736929e+05
# std        23.285669    28.093671     0.275491   12.376099  3.273727e+05
# min      1920.000000    45.000000     7.600000   28.000000  2.508800e+04
# 25%      1976.000000   103.000000     7.700000   70.000000  5.552625e+04
# 50%      1999.000000   119.000000     7.900000   79.000000  1.385485e+05
# 75%      2009.000000   137.000000     8.100000   87.000000  3.741612e+05
# max      2020.000000   321.000000     9.300000  100.000000  2.343110e+06
#
#               Gross
# count  8.310000e+02
# mean   6.803475e+07
# std    1.097500e+08
# min    1.305000e+03
# 25%    3.253559e+06
# 50%    2.353089e+07
# 75%    8.075089e+07
# max    9.366622e+08

# %%
df['IMDB_Rating'].describe()
# Out:
# count    1000.000000
# mean        7.949300
# std         0.275491
# min         7.600000
# 25%         7.700000
# 50%         7.900000
# 75%         8.100000
# max         9.300000
# Name: IMDB_Rating, dtype: float64

# %%
df['IMDB_Rating'].median()
# Out:
# np.float64(7.9)

# %%
df['Runtime'].describe()
# Out:
# count    1000.000000
# mean      122.891000
# std        28.093671
# min        45.000000
# 25%       103.000000
# 50%       119.000000
# 75%       137.000000
# max       321.000000
# Name: Runtime, dtype: float64

# %%
df['Runtime'].median()
# Out:
# np.float64(119.0)

# %%
df['No_of_Votes'].describe()
# Out:
# count    1.000000e+03
# mean     2.736929e+05
# std      3.273727e+05
# min      2.508800e+04
# 25%      5.552625e+04
# 50%      1.385485e+05
# 75%      3.741612e+05
# max      2.343110e+06
# Name: No_of_Votes, dtype: float64

# %%
df['No_of_Votes'].median()
# Out:
# np.float64(138548.5)

# %%
df['No_of_Votes'].mean()
# Out:
# np.float64(273692.911)

# %%
df['No_of_Votes'].min()
# Out:
# np.int64(25088)

# %%
df.describe(include='object')
# Out:
#                                               Poster_Link Series_Title  \
# count                                                1000         1000
# unique                                               1000          999
# top     https://m.media-amazon.com/images/M/MV5BMTY5OD...     Drishyam
# freq                                                    1            2
#
#        Certificate  Genre                                           Overview  \
# count         1000   1000                                               1000
# unique          17    202                                               1000
# top              U  Drama  A man in London tries to help a counter-espion...
# freq           234     85                                                  1
#
#                 Director      Star1        Star2         Star3          Star4
# count               1000       1000         1000          1000           1000
# ...

# %%
df.nunique()
# Out:
# Poster_Link      1000
# Series_Title      999
# Released_Year      99
# Certificate        17
# Runtime           140
# Genre             202
# IMDB_Rating        17
# Overview         1000
# Meta_score         63
# Director          548
# Star1             660
# Star2             841
# Star3             891
# Star4             939
# No_of_Votes       999
# Gross             823
# dtype: int64

# %%
df.shape
# Out:
# (1000, 16)

# %% [markdown]
# ## 7. Univariate Analysis

# %% [markdown]
# ### Genre Distribution

# %%
df['Genre']
# Out:
# 0                         Drama
# 1                  Crime, Drama
# 2          Action, Crime, Drama
# 3                  Crime, Drama
# 4                  Crime, Drama
#                  ...
# 995      Comedy, Drama, Romance
# 996              Drama, Western
# 997         Drama, Romance, War
# 998                  Drama, War
# 999    Crime, Mystery, Thriller
# Name: Genre, Length: 1000, dtype: object

# %%
genre_count = df['Genre'].str.split(', ').explode()

# %%
genre_count.head()
# Out:
# 0     Drama
# 1     Crime
# 1     Drama
# 2    Action
# 2     Crime
# Name: Genre, dtype: object

# %%
genre_count.value_counts()
# Out:
# Genre
# Drama        724
# Comedy       233
# Crime        209
# Adventure    196
# Action       189
# Thriller     137
# Romance      125
# Biography    109
# Mystery       99
# Animation     82
# Sci-Fi        67
# Fantasy       66
# History       56
# Family        56
# War           51
# Music         35
# Horror        32
# Western       20
# Film-Noir     19
# Sport         19
# Musical       17
# Name: count, dtype: int64

# %%
genre_count.value_counts().plot(kind='bar', figsize=(10,5))
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.title('Distribution of Movies by Genre')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Certificate Distribution

# %%
df['Certificate'].value_counts()
# Out:
# Certificate
# U           234
# A           197
# UA          175
# R           146
# Unknown     101
# PG-13        43
# PG           37
# Passed       34
# G            12
# Approved     11
# TV-PG         3
# GP            2
# TV-14         1
# Unrated       1
# TV-MA         1
# 16            1
# U/A           1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))

sns.countplot(
    data=df,
    y='Certificate',
    order=df['Certificate'].value_counts().index
)

plt.xlabel('Number of Movies')
plt.ylabel('Certificate')
plt.title('Distribution of Movies by Certificate')

plt.show()

# %% [markdown]
# ### IMDb Rating Distribution

# %%
plt.figure(figsize=(10, 5))

sns.histplot(
    data=df,
    x='IMDB_Rating',
    bins=20,
    kde=True
)

plt.xlabel('IMDb Rating')
plt.ylabel('Number of Movies')
plt.title('Distribution of IMDb Ratings')

plt.show()

# %%
plt.figure(figsize=(10, 3))

sns.boxplot(
    x=df['IMDB_Rating']
)

plt.xlabel('IMDb Rating')
plt.title('Boxplot of IMDb Ratings')

plt.show()

# %% [markdown]
# ### Runtime Distribution

# %%
plt.figure(figsize=(10, 5))

sns.histplot(
    data=df,
    x='Runtime',
    bins=20,
    kde=True
)

plt.xlabel('Runtime (Minutes)')
plt.ylabel('Number of Movies')
plt.title('Distribution of Movie Runtime')

plt.show()

# %%
plt.figure(figsize=(10, 3))

sns.boxplot(
    x=df['Runtime']
)

plt.xlabel('Runtime (Minutes)')
plt.title('Boxplot of Movie Runtime')

plt.show()

# %%
df.nlargest(
    10,
    'Runtime'
)[['Series_Title', 'Runtime']]
# Out:
#                           Series_Title  Runtime
# 140                 Gangs of Wasseypur      321
# 812                             Hamlet      242
# 314                 Gone with the Wind      238
# 71         Once Upon a Time in America      229
# 116                 Lawrence of Arabia      228
# 247  Lagaan: Once Upon a Time in India      224
# 552               The Ten Commandments      220
# 300                            Ben-Hur      212
# 156             Swades: We, the People      210
# 484                       The Irishman      209

# %%
df.nsmallest(
    10,
    'Runtime'
)[['Series_Title', 'Runtime']]
# Out:
#             Series_Title  Runtime
# 194         Sherlock Jr.       45
# 567               Freaks       64
# 320          The General       67
# 127              The Kid       68
# 717            Duck Soup       69
# 719         Frankenstein       70
# 876    The Invisible Man       71
# 920  The Secret of Kells       71
# 318           The Circus       72
# 694   La planète sauvage       72

# %% [markdown]
# ### Number of Votes Distribution

# %%
plt.figure(figsize=(10, 5))

sns.histplot(
    data=df,
    x='No_of_Votes',
    bins=30
)

plt.xlabel('Number of Votes')
plt.ylabel('Number of Movies')
plt.title('Distribution of Number of Votes')

plt.show()

# %%
plt.figure(figsize=(10, 5))

sns.histplot(
    data=df,
    x='No_of_Votes',
    bins=30
)

plt.xscale('log')

plt.xlabel('Number of Votes (Log Scale)')
plt.ylabel('Number of Movies')
plt.title('Distribution of Number of Votes - Log Scale')

plt.show()

# %%
plt.figure(figsize=(10, 3))

sns.boxplot(
    x=df['No_of_Votes']
)

plt.xlabel('Number of Votes')
plt.title('Boxplot of Number of Votes')

plt.show()

# %%
df.nlargest(
    10,
    'No_of_Votes'
)[['Series_Title', 'No_of_Votes', 'IMDB_Rating']]
# Out:
#                                          Series_Title  No_of_Votes  \
# 0                            The Shawshank Redemption      2343110
# 2                                     The Dark Knight      2303232
# 8                                           Inception      2067042
# 9                                          Fight Club      1854740
# 6                                        Pulp Fiction      1826188
# 11                                       Forrest Gump      1809221
# 14                                         The Matrix      1676426
# 10  The Lord of the Rings: The Fellowship of the Ring      1661481
# 5       The Lord of the Rings: The Return of the King      1642758
# 1                                       The Godfather      1620367
#
#     IMDB_Rating
# 0           9.3
# 2           9.0
# 8           8.8
# 9           8.8
# 6           8.9
# 11          8.8
# 14          8.7
# 10          8.8
# 5           8.9
# 1           9.2

# %% [markdown]
# ### Gross Revenue Distribution

# %%
df['Gross'].describe()
# Out:
# count    8.310000e+02
# mean     6.803475e+07
# std      1.097500e+08
# min      1.305000e+03
# 25%      3.253559e+06
# 50%      2.353089e+07
# 75%      8.075089e+07
# max      9.366622e+08
# Name: Gross, dtype: float64

# %%
plt.figure(figsize=(10, 5))

sns.histplot(
    data=df,
    x='Gross',
    bins=30
)

plt.xlabel('Gross Revenue')
plt.ylabel('Number of Movies')
plt.title('Distribution of Movie Gross Revenue')

plt.show()

# %%
plt.figure(figsize=(10, 5))

sns.histplot(
    data=df,
    x='Gross',
    bins=30
)

plt.xscale('log')

plt.xlabel('Gross Revenue (Log Scale)')
plt.ylabel('Number of Movies')
plt.title('Distribution of Movie Gross Revenue - Log Scale')

plt.show()

# %%
plt.figure(figsize=(10, 3))

sns.boxplot(
    x=df['Gross']
)

plt.xlabel('Gross Revenue')
plt.title('Boxplot of Movie Gross Revenue')

plt.show()

# %%
df.nlargest(
    10,
    'Gross'
)[['Series_Title', 'Gross', 'IMDB_Rating']]
# Out:
#                                    Series_Title        Gross  IMDB_Rating
# 477  Star Wars: Episode VII - The Force Awakens  936662225.0          7.9
# 59                            Avengers: Endgame  858373000.0          8.4
# 623                                      Avatar  760507625.0          7.8
# 60                       Avengers: Infinity War  678815482.0          8.4
# 652                                     Titanic  659325379.0          7.8
# 357                                The Avengers  623279547.0          8.0
# 891                               Incredibles 2  608581744.0          7.6
# 2                               The Dark Knight  534858444.0          9.0
# 582                                   Rogue One  532177324.0          7.8
# 63                        The Dark Knight Rises  448139099.0          8.4

# %% [markdown]
# ### Released Year Distribution

# %%
df['Released_Year'].describe()
# Out:
# count    1000.000000
# mean     1991.221000
# std        23.285669
# min      1920.000000
# 25%      1976.000000
# 50%      1999.000000
# 75%      2009.000000
# max      2020.000000
# Name: Released_Year, dtype: float64

# %%
plt.figure(figsize=(12, 5))

sns.histplot(
    data=df,
    x='Released_Year',
    bins=30
)

plt.xlabel('Release Year')
plt.ylabel('Number of Movies')
plt.title('Distribution of IMDb Top 1000 Movies by Release Year')

plt.show()

# %%
year_count = df['Released_Year'].value_counts().sort_index()

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    year_count.index,
    year_count.values
)

plt.xlabel('Release Year')
plt.ylabel('Number of Movies')
plt.title('IMDb Top 1000 Movies by Release Year')

plt.grid(True, alpha=0.3)

plt.show()

# %%
df['Decade'] = (df['Released_Year'] // 10) * 10

# %%
df[['Released_Year', 'Decade']].head()
# Out:
#    Released_Year  Decade
# 0         1994.0  1990.0
# 1         1972.0  1970.0
# 2         2008.0  2000.0
# 3         1974.0  1970.0
# 4         1957.0  1950.0

# %%
df['Decade'].value_counts().sort_index()
# Out:
# Decade
# 1920.0     11
# 1930.0     24
# 1940.0     35
# 1950.0     56
# 1960.0     73
# 1970.0     76
# 1980.0     89
# 1990.0    151
# 2000.0    237
# 2010.0    242
# 2020.0      6
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))

sns.countplot(
    data=df,
    x='Decade',
    order=sorted(df['Decade'].dropna().unique())
)

plt.xlabel('Decade')
plt.ylabel('Number of Movies')
plt.title('IMDb Top 1000 Movies by Decade')

plt.show()

# %% [markdown]
# ## 8. Bivariate Analysis

# %% [markdown]
# ### IMDb Rating vs Meta Score

# %%
df[['IMDB_Rating', 'Meta_score']].corr()
# Out:
#              IMDB_Rating  Meta_score
# IMDB_Rating     1.000000    0.268531
# Meta_score      0.268531    1.000000

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='Meta_score',
    y='IMDB_Rating'
)

plt.xlabel('Meta Score')
plt.ylabel('IMDb Rating')
plt.title('IMDb Rating vs Meta Score')

plt.show()

# %% [markdown]
# ### Number of Votes vs IMDb Rating

# %%
df[['No_of_Votes', 'IMDB_Rating']].corr()
# Out:
#              No_of_Votes  IMDB_Rating
# No_of_Votes     1.000000     0.494979
# IMDB_Rating     0.494979     1.000000

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='No_of_Votes',
    y='IMDB_Rating'
)

plt.xlabel('Number of Votes')
plt.ylabel('IMDb Rating')
plt.title('IMDb Rating vs Number of Votes')

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='No_of_Votes',
    y='IMDB_Rating'
)

plt.xscale('log')

plt.xlabel('Number of Votes (Log Scale)')
plt.ylabel('IMDb Rating')
plt.title('IMDb Rating vs Number of Votes - Log Scale')

plt.show()

# %% [markdown]
# ### Runtime vs IMDb Rating

# %%
df[['Runtime', 'IMDB_Rating']].corr()
# Out:
#               Runtime  IMDB_Rating
# Runtime      1.000000     0.243096
# IMDB_Rating  0.243096     1.000000

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='Runtime',
    y='IMDB_Rating'
)

plt.xlabel('Runtime (Minutes)')
plt.ylabel('IMDb Rating')
plt.title('IMDb Rating vs Movie Runtime')

plt.show()

# %% [markdown]
# ### Runtime vs IMDb Rating with Regression Line

# %%
plt.figure(figsize=(10, 6))

sns.regplot(
    data=df,
    x='Runtime',
    y='IMDB_Rating',
    scatter_kws={'alpha': 0.5}
)

plt.xlabel('Runtime (Minutes)')
plt.ylabel('IMDb Rating')
plt.title('Runtime vs IMDb Rating with Regression Line')

plt.show()

# %% [markdown]
# ### Released Year vs IMDb Rating

# %%
df[['Released_Year', 'IMDB_Rating']].corr()
# Out:
#                Released_Year  IMDB_Rating
# Released_Year       1.000000    -0.131152
# IMDB_Rating        -0.131152     1.000000

# %%
plt.figure(figsize=(12, 6))

sns.scatterplot(
    data=df,
    x='Released_Year',
    y='IMDB_Rating'
)

plt.xlabel('Release Year')
plt.ylabel('IMDb Rating')
plt.title('IMDb Rating vs Release Year')

plt.show()

# %% [markdown]
# ### Average IMDb Rating by Decade

# %%
decade_rating = df.groupby('Decade')['IMDB_Rating'].mean()
decade_rating
# Out:
# Decade
# 1920.0    8.127273
# 1930.0    7.966667
# 1940.0    8.025714
# 1950.0    8.058929
# 1960.0    7.973973
# 1970.0    7.969737
# 1980.0    7.953933
# 1990.0    7.960927
# 2000.0    7.899578
# 2010.0    7.924380
# 2020.0    8.133333
# Name: IMDB_Rating, dtype: float64

# %%
plt.figure(figsize=(10, 5))

sns.lineplot(
    x=decade_rating.index,
    y=decade_rating.values,
    marker='o'
)

plt.xlabel('Decade')
plt.ylabel('Average IMDb Rating')
plt.title('Average IMDb Rating by Decade')

plt.show()

# %% [markdown]
# ### IMDb Rating vs Gross Revenue

# %%
df[['IMDB_Rating', 'Gross']].corr()
# Out:
#              IMDB_Rating     Gross
# IMDB_Rating     1.000000  0.095923
# Gross           0.095923  1.000000

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='IMDB_Rating',
    y='Gross'
)

plt.xlabel('IMDb Rating')
plt.ylabel('Gross Revenue')
plt.title('Gross Revenue vs IMDb Rating')

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='IMDB_Rating',
    y='Gross'
)

plt.yscale('log')

plt.xlabel('IMDb Rating')
plt.ylabel('Gross Revenue (Log Scale)')
plt.title('Gross Revenue vs IMDb Rating - Log Scale')

plt.show()

# %% [markdown]
# ### Number of Votes vs Gross Revenue

# %%
df[['No_of_Votes', 'Gross']].corr()
# Out:
#              No_of_Votes     Gross
# No_of_Votes     1.000000  0.574393
# Gross           0.574393  1.000000

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='No_of_Votes',
    y='Gross'
)

plt.xscale('log')
plt.yscale('log')

plt.xlabel('Number of Votes (Log Scale)')
plt.ylabel('Gross Revenue (Log Scale)')
plt.title('Gross Revenue vs Number of Votes')

plt.show()

# %% [markdown]
# ### Genre vs IMDb Rating

# %%
genre_df = df[['Series_Title', 'Genre', 'IMDB_Rating']].copy()

genre_df['Genre'] = genre_df['Genre'].str.split(', ')

genre_df = genre_df.explode('Genre')

# %%
genre_df.head()
# Out:
#                Series_Title   Genre  IMDB_Rating
# 0  The Shawshank Redemption   Drama          9.3
# 1             The Godfather   Crime          9.2
# 1             The Godfather   Drama          9.2
# 2           The Dark Knight  Action          9.0
# 2           The Dark Knight   Crime          9.0

# %%
genre_rating = genre_df.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending=False)
genre_rating
# Out:
# Genre
# War          8.013725
# Western      8.000000
# Film-Noir    7.989474
# Sci-Fi       7.977612
# Mystery      7.967677
# Drama        7.959392
# Crime        7.954545
# History      7.953571
# Adventure    7.952041
# Action       7.948677
# Musical      7.947059
# Biography    7.935780
# Fantasy      7.931818
# Animation    7.930488
# Sport        7.926316
# Romance      7.925600
# Music        7.914286
# Family       7.912500
# Thriller     7.909489
# Comedy       7.903433
# Horror       7.887500
# Name: IMDB_Rating, dtype: float64

# %%
plt.figure(figsize=(10, 6))

sns.barplot(
    x=genre_rating.values,
    y=genre_rating.index
)

plt.xlabel('Average IMDb Rating')
plt.ylabel('Genre')
plt.title('Average IMDb Rating by Genre')

plt.show()

# %%
genre_summary = genre_df.groupby('Genre')['IMDB_Rating'].agg(['mean', 'count']).sort_values(
    'mean',
    ascending=False
)

genre_summary
# Out:
#                mean  count
# Genre
# War        8.013725     51
# Western    8.000000     20
# Film-Noir  7.989474     19
# Sci-Fi     7.977612     67
# Mystery    7.967677     99
# Drama      7.959392    724
# Crime      7.954545    209
# History    7.953571     56
# Adventure  7.952041    196
# Action     7.948677    189
# Musical    7.947059     17
# Biography  7.935780    109
# Fantasy    7.931818     66
# Animation  7.930488     82
# Sport      7.926316     19
# Romance    7.925600    125
# Music      7.914286     35
# Family     7.912500     56
# Thriller   7.909489    137
# Comedy     7.903433    233
# Horror     7.887500     32

# %% [markdown]
# ### Certificate vs IMDb Rating

# %%
plt.figure(figsize=(12, 6))

sns.boxplot(
    data=df,
    x='Certificate',
    y='IMDB_Rating'
)

plt.xlabel('Certificate')
plt.ylabel('IMDb Rating')
plt.title('IMDb Rating Distribution by Certificate')

plt.xticks(rotation=45)

plt.show()

# %%
certificate_rating = df.groupby('Certificate')['IMDB_Rating'].agg(['mean', 'median', 'count']).sort_values(
    'mean',
    ascending=False
)

certificate_rating
# Out:
#                  mean  median  count
# Certificate
# TV-14        8.300000    8.30      1
# 16           8.100000    8.10      1
# TV-MA        8.100000    8.10      1
# Unrated      8.100000    8.10      1
# Passed       8.020588    8.05     34
# G            8.000000    8.00     12
# A            7.998985    8.00    197
# U            7.976923    8.00    234
# UA           7.957143    7.90    175
# Approved     7.945455    8.00     11
# Unknown      7.931683    7.90    101
# PG           7.927027    7.90     37
# TV-PG        7.900000    8.00      3
# R            7.869863    7.80    146
# GP           7.850000    7.85      2
# PG-13        7.797674    7.70     43
# U/A          7.600000    7.60      1

# %% [markdown]
# ## 9. Multivariate Analysis

# %% [markdown]
# ### Select Numerical Columns

# %%
numeric_df = df.select_dtypes(include='number')

# %%
numeric_df.head()
# Out:
#    Released_Year  Runtime  IMDB_Rating  Meta_score  No_of_Votes        Gross  \
# 0         1994.0      142          9.3        80.0      2343110   28341469.0
# 1         1972.0      175          9.2       100.0      1620367  134966411.0
# 2         2008.0      152          9.0        84.0      2303232  534858444.0
# 3         1974.0      202          9.0        90.0      1129952   57300000.0
# 4         1957.0       96          9.0        96.0       689845    4360000.0
#
#    Decade
# 0  1990.0
# 1  1970.0
# 2  2000.0
# 3  1970.0
# 4  1950.0

# %%
numeric_df.columns
# Out:
# Index(['Released_Year', 'Runtime', 'IMDB_Rating', 'Meta_score', 'No_of_Votes',
#        'Gross', 'Decade'],
#       dtype='object')

# %%
numeric_df = df[['Released_Year', 'Runtime', 'IMDB_Rating', 'Meta_score', 'No_of_Votes', 'Gross']]

# %% [markdown]
# ### Create Correlation Matrix

# %%
correlation = numeric_df.corr()
correlation
# Out:
#                Released_Year   Runtime  IMDB_Rating  Meta_score  No_of_Votes  \
# Released_Year       1.000000  0.165873    -0.131152   -0.339279     0.241779
# Runtime             0.165873  1.000000     0.243096   -0.031452     0.173264
# IMDB_Rating        -0.131152  0.243096     1.000000    0.268531     0.494979
# Meta_score         -0.339279 -0.031452     0.268531    1.000000    -0.018507
# No_of_Votes         0.241779  0.173264     0.494979   -0.018507     1.000000
# Gross               0.233178  0.139671     0.095923   -0.030587     0.574393
#
#                   Gross
# Released_Year  0.233178
# Runtime        0.139671
# IMDB_Rating    0.095923
# Meta_score    -0.030587
# No_of_Votes    0.574393
# Gross          1.000000

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.figure(figsize=(10, 7))

sns.heatmap(
    correlation,
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title('Correlation Heatmap of Numerical Variables')

plt.show()

# %% [markdown]
# ### Find the Strongest Correlations

# %%
corr_pairs = correlation.unstack()
corr_pairs.head(10)
# Out:
# Released_Year  Released_Year    1.000000
#                Runtime          0.165873
#                IMDB_Rating     -0.131152
#                Meta_score      -0.339279
#                No_of_Votes      0.241779
#                Gross            0.233178
# Runtime        Released_Year    0.165873
#                Runtime          1.000000
#                IMDB_Rating      0.243096
#                Meta_score      -0.031452
# dtype: float64

# %% [markdown]
# ## 10. Outlier Analysis

# %% [markdown]
# ### IMDb Rating Outliers

# %%
plt.figure(figsize=(10, 4))

sns.boxplot(x=df['IMDB_Rating'])

plt.xlabel('IMDb Rating')
plt.title('Outliers in IMDb Ratings')

plt.show()

# %% [markdown]
# ### Runtime Outliers

# %%
plt.figure(figsize=(10, 4))

sns.boxplot(x=df['Runtime'])

plt.xlabel('Runtime (Minutes)')
plt.title('Outliers in Movie Runtime')

plt.show()

# %%
df.nlargest(10, 'Runtime')[['Series_Title', 'Runtime']]
# Out:
#                           Series_Title  Runtime
# 140                 Gangs of Wasseypur      321
# 812                             Hamlet      242
# 314                 Gone with the Wind      238
# 71         Once Upon a Time in America      229
# 116                 Lawrence of Arabia      228
# 247  Lagaan: Once Upon a Time in India      224
# 552               The Ten Commandments      220
# 300                            Ben-Hur      212
# 156             Swades: We, the People      210
# 484                       The Irishman      209

# %% [markdown]
# ### Number of Votes Outliers

# %%
plt.figure(figsize=(10, 4))

sns.boxplot(x=df['No_of_Votes'])

plt.xlabel('Number of Votes')
plt.title('Outliers in Number of Votes')

plt.show()

# %%
df.nlargest(10, 'No_of_Votes')[['Series_Title', 'No_of_Votes', 'IMDB_Rating']]
# Out:
#                                          Series_Title  No_of_Votes  \
# 0                            The Shawshank Redemption      2343110
# 2                                     The Dark Knight      2303232
# 8                                           Inception      2067042
# 9                                          Fight Club      1854740
# 6                                        Pulp Fiction      1826188
# 11                                       Forrest Gump      1809221
# 14                                         The Matrix      1676426
# 10  The Lord of the Rings: The Fellowship of the Ring      1661481
# 5       The Lord of the Rings: The Return of the King      1642758
# 1                                       The Godfather      1620367
#
#     IMDB_Rating
# 0           9.3
# 2           9.0
# 8           8.8
# 9           8.8
# 6           8.9
# 11          8.8
# 14          8.7
# 10          8.8
# 5           8.9
# 1           9.2

# %% [markdown]
# ### Gross Revenue Outliers

# %%
plt.figure(figsize=(10, 4))

sns.boxplot(x=df['Gross'])

plt.xlabel('Gross Revenue')
plt.title('Outliers in Movie Gross Revenue')

plt.show()

# %%
df.nlargest(10, 'Gross')[['Series_Title', 'Gross', 'IMDB_Rating']]
# Out:
#                                    Series_Title        Gross  IMDB_Rating
# 477  Star Wars: Episode VII - The Force Awakens  936662225.0          7.9
# 59                            Avengers: Endgame  858373000.0          8.4
# 623                                      Avatar  760507625.0          7.8
# 60                       Avengers: Infinity War  678815482.0          8.4
# 652                                     Titanic  659325379.0          7.8
# 357                                The Avengers  623279547.0          8.0
# 891                               Incredibles 2  608581744.0          7.6
# 2                               The Dark Knight  534858444.0          9.0
# 582                                   Rogue One  532177324.0          7.8
# 63                        The Dark Knight Rises  448139099.0          8.4

# %% [markdown]
# ## 11. GroupBy Analysis

# %% [markdown]
# ### Average IMDb Rating by Genre

# %%
genre_rating = genre_df.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending=False)

genre_rating
# Out:
# Genre
# War          8.013725
# Western      8.000000
# Film-Noir    7.989474
# Sci-Fi       7.977612
# Mystery      7.967677
# Drama        7.959392
# Crime        7.954545
# History      7.953571
# Adventure    7.952041
# Action       7.948677
# Musical      7.947059
# Biography    7.935780
# Fantasy      7.931818
# Animation    7.930488
# Sport        7.926316
# Romance      7.925600
# Music        7.914286
# Family       7.912500
# Thriller     7.909489
# Comedy       7.903433
# Horror       7.887500
# Name: IMDB_Rating, dtype: float64

# %%
plt.figure(figsize=(10, 6))

sns.barplot(
    x=genre_rating.values,
    y=genre_rating.index
)

plt.xlabel('Average IMDb Rating')
plt.ylabel('Genre')
plt.title('Average IMDb Rating by Genre')

plt.show()

# %% [markdown]
# ### Number of Movies by Genre

# %%
genre_count = genre_df['Genre'].value_counts()
genre_count
# Out:
# Genre
# Drama        724
# Comedy       233
# Crime        209
# Adventure    196
# Action       189
# Thriller     137
# Romance      125
# Biography    109
# Mystery       99
# Animation     82
# Sci-Fi        67
# Fantasy       66
# History       56
# Family        56
# War           51
# Music         35
# Horror        32
# Western       20
# Film-Noir     19
# Sport         19
# Musical       17
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))

sns.barplot(
    x=genre_count.values,
    y=genre_count.index
)

plt.xlabel('Number of Movies')
plt.ylabel('Genre')
plt.title('Number of Movies by Genre')

plt.show()

# %% [markdown]
# ### Genre Summary

# %%
genre_summary = genre_df.groupby('Genre')['IMDB_Rating'].agg(
    ['mean', 'count']
).sort_values(
    'mean',
    ascending=False
)

genre_summary
# Out:
#                mean  count
# Genre
# War        8.013725     51
# Western    8.000000     20
# Film-Noir  7.989474     19
# Sci-Fi     7.977612     67
# Mystery    7.967677     99
# Drama      7.959392    724
# Crime      7.954545    209
# History    7.953571     56
# Adventure  7.952041    196
# Action     7.948677    189
# Musical    7.947059     17
# Biography  7.935780    109
# Fantasy    7.931818     66
# Animation  7.930488     82
# Sport      7.926316     19
# Romance    7.925600    125
# Music      7.914286     35
# Family     7.912500     56
# Thriller   7.909489    137
# Comedy     7.903433    233
# Horror     7.887500     32

# %% [markdown]
# ### Top Directors by Number of Movies

# %%
director_count = df['Director'].value_counts()
director_count.head(10)
# Out:
# Director
# Alfred Hitchcock     14
# Steven Spielberg     13
# Hayao Miyazaki       11
# Akira Kurosawa       10
# Martin Scorsese      10
# Woody Allen           9
# Stanley Kubrick       9
# Billy Wilder          9
# Clint Eastwood        8
# Christopher Nolan     8
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))

sns.barplot(
    x=director_count.head(10).values,
    y=director_count.head(10).index
)

plt.xlabel('Number of Movies')
plt.ylabel('Director')
plt.title('Top 10 Directors by Number of Movies')

plt.show()

# %% [markdown]
# ### Average IMDb Rating by Director

# %%
director_rating = df.groupby('Director')['IMDB_Rating'].agg(
    ['mean', 'count']
)

# %%
director_rating.sort_values('mean', ascending=False).head(10)
# Out:
#                     mean  count
# Director
# Frank Darabont      8.95      2
# Lana Wachowski      8.70      1
# Irvin Kershner      8.70      1
# Masaki Kobayashi    8.60      1
# Fernando Meirelles  8.60      1
# George Lucas        8.60      1
# Sudha Kongara       8.60      1
# Thomas Kail         8.60      1
# Roberto Benigni     8.60      1
# Milos Forman        8.50      2
